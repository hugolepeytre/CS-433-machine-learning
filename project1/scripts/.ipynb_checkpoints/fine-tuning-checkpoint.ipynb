# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
# %load_ext autoreload
# %autoreload 2

# %%
from proj1_helpers import *
from split_data import *
from data_processing import *
from pipeline import *
from cross_validation import find_best_parameter

# %%
DATA_FOLDER = '../data/'
DATA_ZIP = DATA_FOLDER + 'datasets.zip'

DATA_TRAIN_PATH = DATA_FOLDER + 'train.csv'
DATA_TEST_PATH = DATA_FOLDER + 'test.csv' 

y, tX, ids = load_csv_data(DATA_TRAIN_PATH)
y_test, tX_test, ids_test = load_csv_data(DATA_TEST_PATH)
Y_train, X_train, IDS_train, Y_test, X_test, IDS_test = clean_by_cat(y, tX, ids, y_test, tX_test, ids_test)

# %% [markdown]
# # Least Squares

# %%
values = np.arange(20)
model_name = 'least_squares'
parameter_name = 'poly_exp'

for i in range(4):
    best_value, best_loss = find_best_parameter(Y_train[i], X_train[i], model_name, parameter_name, values, logspace=False)
    print("Best {} for {} on category {} is {} with test accuracy averaging at {}".format(parameter_name, model_name, i+1, best_value, best_loss))
# Out:
# Best poly_exp for least_squares on category 1 is 5 with test accuracy averaging at 0.8010091405435249
# Best poly_exp for least_squares on category 2 is 7 with test accuracy averaging at 0.7813650419673097
# Best poly_exp for least_squares on category 3 is 5 with test accuracy averaging at 0.8111160040261701
# Best poly_exp for least_squares on category 4 is 8 with test accuracy averaging at 0.8167245735944408

# %% [markdown]
# # Ridge Regression

# %% [markdown]
# Testing lambda values with polynomial expansion degree 5 (arbitrary)

# %%
values = np.logspace(-4, 3, 30)
model_name = 'ridge_regression'
parameter_name = 'lambda_'

for i in range(4):
    best_value, best_acc = find_best_parameter(Y_train[i], X_train[i], model_name, parameter_name, values, logspace=True, poly_exp=5)
    print("Best {} for {} on category {} is {} with test accuracy averaging at {}".format(parameter_name, model_name, i+1, best_value, best_acc))
# Out:
# Best lambda_ for ridge_regression on category 1 is 0.0003039195382313198 with test accuracy averaging at 0.8009938040611004
# Best lambda_ for ridge_regression on category 2 is 0.0028072162039411755 with test accuracy averaging at 0.7811993815343837
# Best lambda_ for ridge_regression on category 3 is 0.0005298316906283707 with test accuracy averaging at 0.8111474584801208
# Best lambda_ for ridge_regression on category 4 is 0.0028072162039411755 with test accuracy averaging at 0.8164876816171825

# %% [markdown]
# Keeping lambda low but above zero, we look for best degree again

# %%
values = np.arange(20)
model_name = 'ridge_regression'
parameter_name = 'poly_exp'

for i in range(4):
    best_value, best_acc = find_best_parameter(Y_train[i], X_train[i], model_name, parameter_name, values, logspace=False, lambda_=0.0003)
    print("Best {} for {} on category {} is {} with test accuracy averaging at {}".format(parameter_name, model_name, i+1, best_value, best_acc))
# Out:
# Best poly_exp for ridge_regression on category 1 is 5 with test accuracy averaging at 0.8009784675786762
# Best poly_exp for ridge_regression on category 2 is 15 with test accuracy averaging at 0.7819724635547047
# Best poly_exp for ridge_regression on category 3 is 5 with test accuracy averaging at 0.8109587317564166
# Best poly_exp for ridge_regression on category 4 is 9 with test accuracy averaging at 0.8171193935565382

# %% [markdown]
# # Logistic Regression

# %% [markdown]
# Testing for gamma values with polynomial expansion 1 to 3

# %%
values = np.logspace(-4, 3, 30)
model_name = 'logistic_regression'
parameter_name = 'gamma'

for i in range(4):
    best_value, best_acc = find_best_parameter(Y_train[i], X_train[i], model_name, parameter_name, values, poly_exp=1, max_iters=300)
    print("Best {} for {} on category {} is {} with test accuracy averaging at {}".format(parameter_name, model_name, i+1, best_value, best_acc))
# Out:
# C:\Users\Moi\Desktop\Desktop\EPFL\Master\MA1\CS-433 - Machine Learning\CS-433-machine-learning\project1\scripts\logistic_regression.py:7: RuntimeWarning: overflow encountered in exp
#   inv_exp = np.exp(-t)
# C:\Users\Moi\Desktop\Desktop\EPFL\Master\MA1\CS-433 - Machine Learning\CS-433-machine-learning\project1\scripts\costs.py:28: RuntimeWarning: overflow encountered in exp
#   sum_logs = np.log(np.exp(prediction) + 1).sum()
# Best gamma for logistic_regression on category 1 is 0.4175318936560405 with test accuracy averaging at 0.7877890926936998
# C:\Users\Moi\Desktop\Desktop\EPFL\Master\MA1\CS-433 - Machine Learning\CS-433-machine-learning\project1\scripts\costs.py:28: RuntimeWarning: overflow encountered in exp
#   sum_logs = np.log(np.exp(prediction) + 1).sum()
# C:\Users\Moi\Desktop\Desktop\EPFL\Master\MA1\CS-433 - Machine Learning\CS-433-machine-learning\project1\scripts\logistic_regression.py:7: RuntimeWarning: overflow encountered in exp
#   inv_exp = np.exp(-t)
# Best gamma for logistic_regression on category 2 is 0.1373823795883264 with test accuracy averaging at 0.725813576792814
# C:\Users\Moi\Desktop\Desktop\EPFL\Master\MA1\CS-433 - Machine Learning\CS-433-machine-learning\project1\scripts\costs.py:28: RuntimeWarning: overflow encountered in exp
#   sum_logs = np.log(np.exp(prediction) + 1).sum()
# C:\Users\Moi\Desktop\Desktop\EPFL\Master\MA1\CS-433 - Machine Learning\CS-433-machine-learning\project1\scripts\logistic_regression.py:7: RuntimeWarning: overflow encountered in exp
#   inv_exp = np.exp(-t)
# Best gamma for logistic_regression on category 3 is 0.7278953843983154 with test accuracy averaging at 0.7734964771011575
# C:\Users\Moi\Desktop\Desktop\EPFL\Master\MA1\CS-433 - Machine Learning\CS-433-machine-learning\project1\scripts\logistic_regression.py:7: RuntimeWarning: overflow encountered in exp
#   inv_exp = np.exp(-t)
# C:\Users\Moi\Desktop\Desktop\EPFL\Master\MA1\CS-433 - Machine Learning\CS-433-machine-learning\project1\scripts\costs.py:28: RuntimeWarning: overflow encountered in exp
#   sum_logs = np.log(np.exp(prediction) + 1).sum()
# Best gamma for logistic_regression on category 4 is 1.2689610031679235 with test accuracy averaging at 0.7679248262792168

# %%
values = np.logspace(-4, 3, 30)
model_name = 'logistic_regression'
parameter_name = 'gamma'

for i in range(4):
    best_value, best_acc = find_best_parameter(Y_train[i], X_train[i], model_name, parameter_name, values, poly_exp=2, max_iters=300)
    print("Best {} for {} on category {} is {} with test accuracy averaging at {}".format(parameter_name, model_name, i+1, best_value, best_acc))
# Out:
# C:\Users\Moi\Desktop\Desktop\EPFL\Master\MA1\CS-433 - Machine Learning\CS-433-machine-learning\project1\scripts\logistic_regression.py:7: RuntimeWarning: overflow encountered in exp
#   inv_exp = np.exp(-t)
# C:\Users\Moi\Desktop\Desktop\EPFL\Master\MA1\CS-433 - Machine Learning\CS-433-machine-learning\project1\scripts\costs.py:28: RuntimeWarning: overflow encountered in exp
#   sum_logs = np.log(np.exp(prediction) + 1).sum()
# Best gamma for logistic_regression on category 1 is 0.2395026619987486 with test accuracy averaging at 0.7992761180295688
# C:\Users\Moi\Desktop\Desktop\EPFL\Master\MA1\CS-433 - Machine Learning\CS-433-machine-learning\project1\scripts\logistic_regression.py:7: RuntimeWarning: overflow encountered in exp
#   inv_exp = np.exp(-t)
# C:\Users\Moi\Desktop\Desktop\EPFL\Master\MA1\CS-433 - Machine Learning\CS-433-machine-learning\project1\scripts\costs.py:28: RuntimeWarning: overflow encountered in exp
#   sum_logs = np.log(np.exp(prediction) + 1).sum()
# Best gamma for logistic_regression on category 2 is 0.2395026619987486 with test accuracy averaging at 0.7760823148284495
# C:\Users\Moi\Desktop\Desktop\EPFL\Master\MA1\CS-433 - Machine Learning\CS-433-machine-learning\project1\scripts\costs.py:28: RuntimeWarning: overflow encountered in exp
#   sum_logs = np.log(np.exp(prediction) + 1).sum()
# C:\Users\Moi\Desktop\Desktop\EPFL\Master\MA1\CS-433 - Machine Learning\CS-433-machine-learning\project1\scripts\logistic_regression.py:7: RuntimeWarning: overflow encountered in exp
#   inv_exp = np.exp(-t)
# Best gamma for logistic_regression on category 3 is 0.4175318936560405 with test accuracy averaging at 0.8045734776044289
# C:\Users\Moi\Desktop\Desktop\EPFL\Master\MA1\CS-433 - Machine Learning\CS-433-machine-learning\project1\scripts\logistic_regression.py:7: RuntimeWarning: overflow encountered in exp
#   inv_exp = np.exp(-t)
# C:\Users\Moi\Desktop\Desktop\EPFL\Master\MA1\CS-433 - Machine Learning\CS-433-machine-learning\project1\scripts\costs.py:28: RuntimeWarning: overflow encountered in exp
#   sum_logs = np.log(np.exp(prediction) + 1).sum()
# Best gamma for logistic_regression on category 4 is 0.2395026619987486 with test accuracy averaging at 0.8098547062539482

# %%
values = np.logspace(-4, 3, 30)
model_name = 'logistic_regression'
parameter_name = 'gamma'

for i in range(4):
    best_value, best_acc = find_best_parameter(Y_train[i], X_train[i], model_name, parameter_name, values, poly_exp=3, max_iters=300)
    print("Best {} for {} on category {} is {} with test accuracy averaging at {}".format(parameter_name, model_name, i+1, best_value, best_acc))
# Out:
# C:\Users\Moi\Desktop\Desktop\EPFL\Master\MA1\CS-433 - Machine Learning\CS-433-machine-learning\project1\scripts\logistic_regression.py:7: RuntimeWarning: overflow encountered in exp
#   inv_exp = np.exp(-t)
# C:\Users\Moi\Desktop\Desktop\EPFL\Master\MA1\CS-433 - Machine Learning\CS-433-machine-learning\project1\scripts\costs.py:28: RuntimeWarning: overflow encountered in exp
#   sum_logs = np.log(np.exp(prediction) + 1).sum()
# Best gamma for logistic_regression on category 1 is 0.1373823795883264 with test accuracy averaging at 0.8003189988344273
# C:\Users\Moi\Desktop\Desktop\EPFL\Master\MA1\CS-433 - Machine Learning\CS-433-machine-learning\project1\scripts\costs.py:28: RuntimeWarning: overflow encountered in exp
#   sum_logs = np.log(np.exp(prediction) + 1).sum()
# C:\Users\Moi\Desktop\Desktop\EPFL\Master\MA1\CS-433 - Machine Learning\CS-433-machine-learning\project1\scripts\logistic_regression.py:7: RuntimeWarning: overflow encountered in exp
#   inv_exp = np.exp(-t)
# Best gamma for logistic_regression on category 2 is 0.07880462815669913 with test accuracy averaging at 0.7762479752613753
# C:\Users\Moi\Desktop\Desktop\EPFL\Master\MA1\CS-433 - Machine Learning\CS-433-machine-learning\project1\scripts\costs.py:28: RuntimeWarning: overflow encountered in exp
#   sum_logs = np.log(np.exp(prediction) + 1).sum()
# C:\Users\Moi\Desktop\Desktop\EPFL\Master\MA1\CS-433 - Machine Learning\CS-433-machine-learning\project1\scripts\logistic_regression.py:7: RuntimeWarning: overflow encountered in exp
#   inv_exp = np.exp(-t)
# Best gamma for logistic_regression on category 3 is 0.07880462815669913 with test accuracy averaging at 0.8042589330649221
# C:\Users\Moi\Desktop\Desktop\EPFL\Master\MA1\CS-433 - Machine Learning\CS-433-machine-learning\project1\scripts\logistic_regression.py:7: RuntimeWarning: overflow encountered in exp
#   inv_exp = np.exp(-t)
# C:\Users\Moi\Desktop\Desktop\EPFL\Master\MA1\CS-433 - Machine Learning\CS-433-machine-learning\project1\scripts\costs.py:28: RuntimeWarning: overflow encountered in exp
#   sum_logs = np.log(np.exp(prediction) + 1).sum()
# Best gamma for logistic_regression on category 4 is 0.1373823795883264 with test accuracy averaging at 0.8107233101705622

# %% [markdown]
# Adjusting max_iters

# %%
values = (np.arange(20)+1)*50
model_name = 'logistic_regression'
parameter_name = 'max_iters'

for i in range(4):
    best_value, best_acc = find_best_parameter(Y_train[i], X_train[i], model_name, parameter_name, values, logspace=False, gamma=0.1, poly_exp=3)
    print("Best {} for {} on category {} is {} with test accuracy averaging at {}".format(parameter_name, model_name, i+1, best_value, best_acc))
# Out:
# Best max_iters for logistic_regression on category 1 is 1000 with test accuracy averaging at 0.8015459174283788
# Best max_iters for logistic_regression on category 2 is 900 with test accuracy averaging at 0.7801870122220587
# Best max_iters for logistic_regression on category 3 is 750 with test accuracy averaging at 0.8073100150981378
# Best max_iters for logistic_regression on category 4 is 950 with test accuracy averaging at 0.8156190777005685
