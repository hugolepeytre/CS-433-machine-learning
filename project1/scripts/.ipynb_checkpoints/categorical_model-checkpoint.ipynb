# %%
# Useful starting lines
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# /Applications/anaconda3/lib/python3.7/site-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
# %load_ext autoreload
# %autoreload 2

from proj1_helpers import *
from split_data import *
from data_processing import *
from pipeline import * 
from cross_validation import *
from split_data import *

# %%
DATA_FOLDER = '../data/'
DATA_ZIP = DATA_FOLDER + 'datasets.zip'

DATA_TRAIN_PATH = DATA_FOLDER + 'train.csv'
DATA_TEST_PATH = DATA_FOLDER + 'test.csv'

# %%
y, tX, ids = load_csv_data(DATA_TRAIN_PATH)

# %%
y_test, tX_test, ids_test = load_csv_data(DATA_TEST_PATH)

# %%
split_ratio = 0.8
y_train, tX_train, ids_train, y_validation, tX_validation, ids_validation = split_data(tX, y, split_ratio, ids=ids)

# %%
Y_train, X_train, IDS_train, Y_test, X_test, IDS_test = clean_by_cat(y_train, tX_train, ids_train, y_test, tX_test, ids_test)

# %%
len(X_train[0])
# Out:
# 52182

# %%
DEGREE = 2

# %%
from implementations import *

# %%
def fit(Y, X, IDS):
    W = []
    for i in range(len(Y)): 
        y_cat, tX_cat, ids_cat = Y[i], X[i], IDS[i]
        initial_w = np.zeros(tX_cat.shape[1])
        w, loss = model_data(y_cat, tX_cat, 'least_squares', poly_exp=DEGREE)
        W.append(w)
    return W, loss

# %%
def prediction_by_cat(W, X, IDS):
    y_pred = np.array([])
    ids_pred = np.array([])
    for w, tX, ids in zip(W, X, IDS):
        tX_poly = build_poly_2D(tX, DEGREE)
        if False: # Only for logistic regression, we will do something nice later
            y_pred = np.c_[y_pred,predict_labels_logistic(w, tX_poly)]
        else:
            prediction = predict_labels(w, tX_poly)
            y_pred = np.concatenate((y_pred, prediction)) if len(y_pred) else prediction
        ids_pred = np.concatenate((ids_pred, ids)) if len(ids_pred) else ids
    return y_pred, ids_pred

# %%
def model_accuracy_by_cat(Y_train, X_train, Y_validation, X_validation, IDS):
    W, loss = fit(Y_train, X_train, IDS)
    y_pred, ids_pred = prediction_by_cat(W, X_validation, IDS)
    return (y_pred == np.hstack(Y_validation,)).sum() / len(y_pred)

# %%
Y_train, X_train, IDS_train, Y_validation, X_validation, IDS_validation = clean_by_cat(y_train, tX_train, ids_train, y_validation, tX_validation, ids_validation)

# %%
model_accuracy_by_cat(Y_train, X_train, Y_validation, X_validation, IDS_validation)
# Out:
# 0.80936

# %%
def create_by_cat_submission(Y_train, X_train, IDS_train, X_test, IDS_test):   
    W = fit(Y_train, X_train, IDS_train)
    y_pred, ids_pred = prediction_by_cat(W, X_test, IDS_test)
    OUTPUT_PATH = DATA_FOLDER + 'submission.csv'
    create_csv_submission(ids_pred, y_pred, OUTPUT_PATH)

# %%
# create_by_cat_submission(Y_train, X_train, IDS_train, X_test, IDS_test)

# %% [markdown]
# # Plot

# %%
import pandas as pd
fig, axes = plt.subplots(10,2, figsize=(20,25))
df_col_clean = pd.DataFrame(data=X_train[0])
for i, col in enumerate(df_col_clean.columns):
    ax = axes[i // 2, i%2]
    sns.histplot(data=df_col_clean.loc[:,col], ax=ax)
fig.tight_layout()

# %%
fig, axes = plt.subplots(10,2, figsize=(20,25))
df_col_clean = pd.DataFrame(data=X_test[0])
for i, col in enumerate(df_col_clean.columns):
    ax = axes[i // 2, i%2]
    sns.histplot(data=df_col_clean.loc[:,col], ax=ax)
fig.tight_layout()

# %%
df = pd.read_csv(DATA_TRAIN_PATH, na_values=-999)

# %%
df.DER_mass_transverse_met_lep.hist(bins=200)

# %%
df0 = df[df.PRI_jet_num == 0]
df1 = df[df.PRI_jet_num == 1]
df2 = df[df.PRI_jet_num == 2]
df3 = df[df.PRI_jet_num == 3]

# %%
nan_values
# Out:
#         DER_deltaeta_jet_jet  PRI_jet_num
# 1                        NaN            1
# 2                        NaN            1
# 3                        NaN            0
# 4                        NaN            0
# 7                        NaN            1
# ...                      ...          ...
# 249995                   NaN            0
# 249996                   NaN            0
# 249997                   NaN            1
# 249998                   NaN            0
# 249999                   NaN            0
#
# [177457 rows x 2 columns]

# %%
nan_values = df[["DER_deltaeta_jet_jet", "PRI_jet_num"]].copy()
nan_values = nan_values[nan_values.isna().any(axis=1)]
sns.countplot(data=nan_values, x="PRI_jet_num");

# %%
nan_values = df[["DER_mass_MMC", "PRI_jet_num"]].copy()
nan_values = nan_values[nan_values.isna().any(axis=1)]
sns.countplot(data=nan_values, x="PRI_jet_num");

# %%
nan_values = df[["PRI_jet_leading_pt", "PRI_jet_num"]].copy()
nan_values = nan_values[nan_values.isna().any(axis=1)]
sns.countplot(data=nan_values, x="PRI_jet_num");
plt.xticks([0,1,2,3], [0,1,2,3])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-96-f6a6ced4385c> in <module>
#       2 nan_values = nan_values[nan_values.isna().any(axis=1)]
#       3 sns.countplot(data=nan_values, x="PRI_jet_num");
# ----> 4 plt.xticks([0,1,2,3], [0,1,2,3])
#
# TypeError: 'list' object is not callable

# %%
df[df.columns[2:]].shape
# Out:
# (250000, 30)

# %%
nan_values = df[df.columns[2:]].groupby("PRI_jet_num").apply(lambda x: x.isna().sum() / len(x))
sns.heatmap(data=nan_values, cmap="Blues")
plt.title("Proportion of NaN among each category")
plt.savefig("NaN distribution among categories", dpi=300, bbox_inches="tight")

# %%
fig, axes = plt.subplots(10,2, figsize=(20,25))
_, X_raw, _ = group_by_cat(y_train, tX_train, ids_train)

df_col_clean = pd.DataFrame(data=X_raw[0])
for i, col in enumerate(df_col_clean.columns):
    ax = axes[i // 2, i%2]
    sns.histplot(data=df_col_clean.loc[:,col], ax=ax)
fig.tight_layout()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-138-800e96667710> in <module>
#       4 df_col_clean = pd.DataFrame(data=X_raw[0])
#       5 for i, col in enumerate(df_col_clean.columns):
# ----> 6     ax = axes[i // 2, i%2]
#       7     sns.histplot(data=df_col_clean.loc[:,col], ax=ax)
#       8 fig.tight_layout()
#
# IndexError: index 10 is out of bounds for axis 0 with size 10

# %%
fig, axes = plt.subplots(1,2, figsize=(15,5))
_, X_raw, _ = group_by_cat(y_train, tX_train, ids_train)
raw_df = pd.DataFrame(data=X_raw[0])
clean_df = pd.DataFrame(data=X_train[0])

sns.histplot(data=raw_df.loc[:,1], ax=axes[0])
ax.set_xlabel("Raw distribution of the ")
sns.histplot(data=clean_df.loc[:,2], ax=axes[1])
